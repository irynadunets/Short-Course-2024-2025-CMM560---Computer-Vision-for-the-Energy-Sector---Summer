# %% [markdown]
# <a href="https://colab.research.google.com/github/irynadunets/-Short-Course-2024-2025-CMM560---Computer-Vision-for-the-Energy-Sector---Summer/blob/main/Introduction_to_Data_Science_with_Python_Semester_3_Topic_1%2C2%2C3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3a. Using Python as a calculator

# %%
max(2,4)
# Out:
# 2

# %%
min(2,4)
# Out:
# 2

# %%
abs(2)
abs(-2)
# Out:
# 2

# %%
round(3.44556, 2)
# Out:
# 3.45

# %%
y = [1.1, 3.2, 0.9, 2.7, 4.5]
print(y)
# Out:
# [1.1, 3.2, 0.9, 2.7, 4.5]

# %%
type(y)
# Out:
# list

# %%
max(y)
# Out:
# 4.5

# %%
sum(y)
# Out:
# 12.400000000000002

# %%
import math
math.sin(30)
# Out:
# -0.9880316240928618

# %%
math.log10(100)
# Out:
# 2.0

# %%
math.exp(1)
# Out:
# 2.718281828459045

# %%
math.log(100)
# Out:
# 4.605170185988092

# %%
math.sqrt(36)
# Out:
# 6.0

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# 3b. Saving results in variables in Python

# %%
p = 14 *5

# %%
q = math.sqrt(10)

# %%
r = 8 + q

# %%
s = q**2

# %%
t = p * q

# %%
g = p+q

# %%
G = p+q

# %% [markdown]
# 4b. Simple plots in Python

# %%
x = [0,1,2,3,4,5]

# %%
y = [0,1,4,9,16,25]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y)

# %%
plt.plot(x, y, color = 'red')

# %%
plt.scatter(x, y)

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'x': [0,1,2,3,4,5],
'y': [0,1,4,9,16,25]})

# %%
df1.plot.line('x', 'y', color = 'red')
# Out:
# <Axes: xlabel='x'>

# %%
df1.plot.scatter('x', 'y', color = 'green')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
year = ["2016", "2017", "2018", "2019"]

# %%
sales = [350, 270, 40, 600]

# %%
import pandas as pd

# %%
df2 = pd.DataFrame({'sales': [350,270,40,600]},
index = ["2016", "2017", "2018", "2019"])

# %%
# Plot the bar chart
plt.figure(figsize=(8, 6))
plt.bar(df2.index, df2['sales'], color='yellow')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Annual Sales (2016–2019)')

# Show the chart
plt.tight_layout()
plt.show()

# %%
# Create a pie chart from the 'sales' column
df2.plot.pie(y='sales', labels=df2.index, autopct='%1.1f%%', figsize=(6, 6), legend=False)

# Add a title
plt.title('Sales Distribution (2016–2019)')

# Show the chart
plt.tight_layout()
plt.show()

# %%
# Create a bar chart directly from the DataFrame
df2.plot.bar(legend=False, figsize=(8, 5), color='orange')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Annual Sales (2016–2019)')

# Show the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# Topic 2 Task 1 – Enter data manually and explore the variables

# %%
France = [16127955, 15805560, 17386612, 13960064, 4142050]
Germany = [15294292, 20447052, 23900423, 17988340, 5389106]
Italy = [10859356, 13275488, 18594885, 13299743, 4330074]
Spain = [9254305, 11015526, 14787185, 9182427, 2860952]
UK = [15746113, 17509234, 17554612, 13284207, 3437008]

# %%
AgeGroups = ["0-19", "20-39", "40-59", "60-79", "80+"]
Countries = ['France', 'Germany', 'Italy', 'Spain', 'UK']

# %%
import pandas as pd
CountryData = pd.DataFrame({"France":France, "Germany":Germany, "Italy":Italy,
"Spain":Spain, "UK":UK}, index = AgeGroups)

# %%
display(CountryData.info())
# info is a function so has brackets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0-19 to 80+
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   France   5 non-null      int64
#  1   Germany  5 non-null      int64
#  2   Italy    5 non-null      int64
#  3   Spain    5 non-null      int64
#  4   UK       5 non-null      int64
# dtypes: int64(5)
# memory usage: 240.0+ bytes
# None

# %%
display(CountryData.columns)
# columns is a property of the dataframe so does not have brackets
# Out:
# Index(['France', 'Germany', 'Italy', 'Spain', 'UK'], dtype='object')

# %%
# Index (row labels)
print("Index:")
print(CountryData.index)
# Out:
# Index:
# Index(['0-19', '20-39', '40-59', '60-79', '80+'], dtype='object')

# %%
# Shape (rows, columns)
print("\nShape:")
print(CountryData.shape)
# Out:
# Shape:
# (5, 5)

# %%
# Data types of each column
print("\nData types:")
print(CountryData.dtypes)
# Out:
# Data types:
# France     int64
# Germany    int64
# Italy      int64
# Spain      int64
# UK         int64
# dtype: object

# %% [markdown]
# Plot Pie and Bar Charts for Each Country

# %%
# Loop through each country
for country in CountryData.columns:
    values = CountryData[country]

    # Pie Chart
    plt.figure(figsize=(6, 6))
    plt.pie(values, labels=AgeGroups, autopct='%1.1f%%', startangle=140)
    plt.title(f"{country} Age Distribution (Pie Chart)")
    plt.tight_layout()
    plt.show()

    # Bar Chart
    plt.figure(figsize=(8, 5))
    plt.bar(AgeGroups, values, color='skyblue')
    plt.xlabel('Age Group')
    plt.ylabel('Population')
    plt.title(f"{country} Age Distribution (Bar Chart)")
    plt.tight_layout()
    plt.show()

# %% [markdown]
#  Age groups clustered by Country (default DataFrame plot)

# %%
plt.figure(figsize=(10, 6))
CountryData.plot(kind='bar')
plt.title('Population by Age Group Clustered by Country')
plt.xlabel('Age Group')
plt.ylabel('Population')
plt.legend(title='Country')
plt.tight_layout()
plt.show()

# %% [markdown]
# Countries clustered by Age group (transpose DataFrame and plot)

# %%
plt.figure(figsize=(10, 6))
CountryData.T.plot(kind='bar')
plt.title('Population by Country Clustered by Age Group')
plt.xlabel('Country')
plt.ylabel('Population')
plt.legend(title='Age Group')
plt.tight_layout()
plt.show()

# %% [markdown]
# Stacked Bar Chart: Age Groups stacked by Country

# %%
plt.figure(figsize=(10, 6))
CountryData.plot(kind='bar', stacked=True)
plt.title('Population Distribution by Age Group in Each Country (Stacked)')
plt.xlabel('Age Group')
plt.ylabel('Population')
plt.legend(title='Country')
plt.tight_layout()
plt.show()

# %% [markdown]
# Stacked Bar Chart: Countries stacked by Age Group

# %%
plt.figure(figsize=(10, 6))
CountryData.T.plot(kind='bar', stacked=True)
plt.title('Population Distribution by Country in Each Age Group (Stacked)')
plt.xlabel('Country')
plt.ylabel('Population')
plt.legend(title='Age Group')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Age Distribution Comparison Between Countries
# Similarities:
#
# All countries show a decreasing trend in population numbers with increasing age, especially for the oldest group (80+). This is expected due to natural mortality rates.
#
# The middle age groups (20-39 and 40-59) generally hold the highest population numbers, indicating a large working-age population across all countries.
#
# The youngest group (0-19) tends to be sizable but usually smaller than middle age groups, reflecting typical birth rates and demographic trends in developed European countries.
#
# Differences:
#
# Germany and Italy tend to have larger populations in the 40-59 age group compared to other countries, possibly indicating an aging population or baby boomers in that cohort.
#
# France and the UK show relatively higher numbers in the youngest age group (0-19), suggesting either higher birth rates or younger population demographics compared to Germany or Italy.
#
# Spain generally shows smaller population numbers across all groups, which might reflect its smaller overall population or specific demographic trends.
#
# 2. Population Distribution by Age Group Across Countries
# For the youngest group (0-19):
#
# The UK and France have the highest populations, which may suggest stronger population growth or immigration impacting younger demographics.
#
# Spain has the smallest, which could point to lower birth rates or outward migration.
#
# For the working-age groups (20-39, 40-59):
#
# Germany has consistently high numbers, especially in the 40-59 group, which could indicate a large, mature workforce.
#
# Italy also has a large middle-aged population, which may impact future retirement demographics.
#
# For the older groups (60-79 and 80+):
#
# Germany and Italy have larger older populations, which suggests aging populations and potential challenges for healthcare and pensions.
#
# France and the UK show smaller proportions in the oldest age group, potentially reflecting differences in life expectancy or migration patterns.
#
# 3. Implications and Context
# Aging Populations: Countries like Germany and Italy may face increased pressure on social services and healthcare due to larger elderly populations.
#
# Youthful Populations: France and the UK may benefit from a more balanced demographic structure, with higher numbers of younger people entering the workforce.
#
# Migration Effects: Differences in population structures could also reflect immigration trends; countries with higher youth populations might be attracting younger immigrants.
#
# Policy Impact: Governments can use this data to tailor policies on healthcare, pensions, education, and labor markets to the specific demographic realities.
#
# 4. Additional Observations
# Spain’s smaller numbers across all age groups might warrant investigating population decline or migration issues.
#
# The relative sizes of the 80+ groups can give clues about life expectancy and healthcare quality.
#
# Differences in the 0-19 age group could influence future population growth and economic outlooks.

# %% [markdown]
# Task 2 – Load a dataset from a csv file and explore the variables

# %%
import pandas as pd
insurance = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/insurance.csv")

# %%
print(insurance.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   city      1338 non-null   object
#  6   cost      1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# None

# %%
print("\nData types:\n", insurance.dtypes)
# Out:
# Data types:
#  age           int64
# gender       object
# bmi         float64
# children      int64
# smoker       object
# city         object
# cost        float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Bar Chart for Gender
insurance['gender'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Gender Distribution (Bar Chart)')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Pie Chart for Gender
insurance['gender'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Gender Distribution (Pie Chart)')
plt.ylabel('')  # hides y-axis label
plt.tight_layout()
plt.show()

# %% [markdown]
# The bar chart shows how many males vs females are in the dataset.
#
# The pie chart makes it easy to see if the distribution is balanced or skewed

# %%
# Bar Chart for Smoker
insurance['smoker'].value_counts().plot(kind='bar', color='salmon')
plt.title('Smoker Status (Bar Chart)')
plt.xlabel('Smoker')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Pie Chart for Smoker
insurance['smoker'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightgreen', 'lightcoral'])
plt.title('Smoker Status (Pie Chart)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# This shows what proportion of the insured population smokes.

# %%
# Bar Chart for City
insurance['city'].value_counts().plot(kind='bar', color='orange')
plt.title('City-wise Distribution (Bar Chart)')
plt.xlabel('City')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Pie Chart for City
insurance['city'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('City-wise Distribution (Pie Chart)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# This shows how many insured people are from each city.

# %%
# Bar Chart for Children
insurance['children'].value_counts().sort_index().plot(kind='bar', color='lightblue')
plt.title('Number of Children (Bar Chart)')
plt.xlabel('Number of Children')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Pie Chart for Children
insurance['children'].value_counts().sort_index().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=plt.cm.Pastel1.colors)
plt.title('Number of Children (Pie Chart)')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# The bar chart shows the exact count of individuals by number of children (e.g., many with 0 or 1 child).
#
# The pie chart makes it easy to understand proportions.
#
# You may observe that 0 children is the most common, which can be relevant for understanding policy types or family structures.

# %% [markdown]
# Task 3 – Load and explore sample data from the
# seaborn package

# %%
import seaborn
import pandas as pd

# %%
print(seaborn.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = seaborn.load_dataset('titanic')

# %%
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (891, 15)

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
insurance['gender'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Typically, this is a balanced categorical variable.
#
# If you see roughly equal bars for male and female → it's balanced.
#
# If one gender is significantly more frequent → imbalanced, which could bias analyses (e.g. health charges).

# %%
insurance['smoker'].value_counts().plot(kind='bar', color='salmon')
plt.title('Smoker Status Distribution')
plt.xlabel('Smoker')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Often imbalanced — majority may be non-smokers.
#
# This skewed distribution is important because smokers usually have much higher insurance charges.
#
# Use with caution in models — imbalance can affect predictions.

# %%
insurance['city'].value_counts().plot(kind='bar', color='orange')
plt.title('city Distribution')
plt.xlabel('city')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Check whether some regions dominate.
#
# If one or two regions have much higher counts → imbalanced
#
# A uniform distribution would show all regions roughly equal — rarely the case.

# %%
insurance['children'].value_counts().sort_index().plot(kind='bar', color='lightgreen')
plt.title('Number of Children')
plt.xlabel('Children')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Generally right-skewed — most people have 0–2 children.
#
# Not uniformly distributed.
#
# A few people have 4 or 5 children, but they’re rare.
#
# This variable is numeric but acts more like a qualitative label in small-scale distributions.

# %%
df.drop(columns = ['pclass', 'survived',
'embarked'], inplace = True)

# %% [markdown]
# 🎯 Best Candidate for Target Variable:
# ✅ Survived
# Values: 0 = Did not survive, 1 = Survived
#
# Type: Binary (0 or 1)
#
# Why? It represents the outcome we want to predict based on other features.
#
# 🧠 Other Variables in Titanic Dataset (used as Features):
# Variable	Type	Description	Use as Feature?
# Pclass	Ordinal	Passenger class (1, 2, 3)	✅ Yes
# Sex	Categorical	Male or Female	✅ Yes
# Age	Numerical	Age in years	✅ Yes (handle missing)
# SibSp	Numerical	# of siblings/spouses aboard	✅ Yes
# Parch	Numerical	# of parents/children aboard	✅ Yes
# Fare	Numerical	Ticket fare	✅ Yes
# Embarked	Categorical	Port of embarkation (C/Q/S)	✅ Yes
# Name	Text	Passenger name	❌ No (unless feature engineered)
# Ticket	Text	Ticket number	❌ Rarely useful
# Cabin	Categorical	Cabin number	❌ Often missing or inconsistent
#
# 🧠 Summary:
# The target variable is clearly Survived, as it’s the outcome you're trying to predict.
#
# All other variables (except maybe Name, Ticket, and Cabin) are commonly used as features in models like logistic regression, decision trees, or random forests.

# %%
df_1stClass = df[df['class'] == 'First']

# %%
df_65 = df[df['age'] >= 65]

# %% [markdown]
# Topic 3 Task 1 – Statistics of the insurance.csv dataset

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# Load dataset
titanic = sns.load_dataset('titanic')  # or pd.read_csv('titanic.csv')

# Select only numerical columns
num_cols = titanic.select_dtypes(include=['float64', 'int64'])

# Define a function to compute all stats
def numerical_summary(df):
    summary = pd.DataFrame(index=df.columns)
    summary['Mean'] = df.mean()
    summary['Median'] = df.median()
    summary['Range'] = df.max() - df.min()
    summary['IQR'] = df.quantile(0.75) - df.quantile(0.25)
    summary['Std Dev'] = df.std()
    summary['Skewness'] = df.skew()
    summary['Kurtosis'] = df.kurtosis()
    return summary

# Compute summary
summary_stats = numerical_summary(num_cols)
print(summary_stats)
# Out:
#                Mean   Median     Range      IQR    Std Dev  Skewness  \
# survived   0.383838   0.0000    1.0000   1.0000   0.486592  0.478523
# pclass     2.308642   3.0000    2.0000   1.0000   0.836071 -0.630548
# age       29.699118  28.0000   79.5800  17.8750  14.526497  0.389108
# sibsp      0.523008   0.0000    8.0000   1.0000   1.102743  3.695352
# parch      0.381594   0.0000    6.0000   0.0000   0.806057  2.749117
# fare      32.204208  14.4542  512.3292  23.0896  49.693429  4.787317
#
#            Kurtosis
# survived  -1.775005
# pclass    -1.280015
# age        0.178274
# sibsp     17.880420
# parch      9.778125
# fare      33.398141

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numerical variables
num_cols = titanic.select_dtypes(include=['float64', 'int64']).columns

# Create subplots for each variable
for col in num_cols:
    fig, axes = plt.subplots(1, 3, figsize=(18, 4))
    fig.suptitle(f'Distribution of {col}', fontsize=16)

    # Histogram
    sns.histplot(titanic[col].dropna(), kde=False, ax=axes[0], color='skyblue')
    axes[0].set_title('Histogram')

    # Density Plot
    sns.kdeplot(titanic[col].dropna(), ax=axes[1], fill=True, color='orange')
    axes[1].set_title('Density Plot')

    # Boxplot
    sns.boxplot(x=titanic[col], ax=axes[2], color='lightgreen')
    axes[2].set_title('Boxplot')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# 📌 age
# Histogram/Density: Bell-shaped, slightly right-skewed.
#
# Boxplot: Mild right skew, few outliers.
#
# Stats: Skewness ≈ 0.4 → confirms slight right skew.
#
# 🧠 Description: Roughly normal, moderate spread, some outliers in upper range.
#
# 📌 fare
# Histogram/Density: Highly right-skewed, long tail.
#
# Boxplot: Extreme outliers (high fares).
#
# Stats: Skewness > 4, Kurtosis > 30 → confirms strong right skew and heavy tails.
#
# 🧠 Description: Highly skewed, large variance, many outliers.
#
# 📌 sibsp and parch
# Histogram: Discrete values (0,1,2,...), right-skewed.
#
# Boxplot: Many zeros, long upper tail.
#
# Stats: High skewness and kurtosis.
#
# 🧠 Description: Discrete, skewed, not normally distributed, family sizes are small for most.
#
# 📌 pclass
# Histogram: Discrete 1/2/3, more people in 3rd class.
#
# Boxplot: Limited but skewed distribution.
#
# Stats: Skewness ≈ -0.6 → slight left skew.
#
# 🧠 Description: Categorical numeric, not truly continuous; visually skewed left due to 3rd class dominance.
#
# 📌 survived
# Histogram: Binary values 0 or 1.
#
# Boxplot: Not informative — binary.
#
# Stats: Not meaningful for shape; purely a classification target.
#
# 🧠 Description: Binary target; visualization is only useful for proportions.
# | Variable   | Stat Shape         | Visual Shape                         | Description                    |
# | ---------- | ------------------ | ------------------------------------ | ------------------------------ |
# | `age`      | Slight skew        | Slight skew in histogram and boxplot | Near normal with some outliers |
# | `fare`     | High skew/kurtosis | Extreme right skew & outliers        | Highly skewed and heavy-tailed |
# | `sibsp`    | High skew          | Bar-shaped histogram with long tail  | Skewed, mostly 0 or 1          |
# | `parch`    | High skew          | Similar to `sibsp`                   | Skewed, very few large values  |
# | `pclass`   | Slight left skew   | Many 3rd-class passengers            | Skewed due to class imbalance  |
# | `survived` | Binary             | Binary                               | Target variable only           |

# %% [markdown]
# Task 2 – Statistics of the fifa.csv dataset
# STEP 1: Load and Inspect the Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
fifa = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/fifa.csv")

# Check the structure
print(fifa.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18547 entries, 0 to 18546
# Data columns (total 48 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 18547 non-null  int64
#  1   Name               18547 non-null  object
#  2   Nationality        18547 non-null  object
#  3   Age                18547 non-null  int64
#  4   OverallRating      18547 non-null  int64
#  5   Club               18291 non-null  object
#  6   HeightCM           18547 non-null  int64
#  7   HeightFtIn         18547 non-null  object
#  8   WeightKg           18547 non-null  float64
#  9   WeightSt           18547 non-null  object
#  10  PreferredSide      18547 non-null  object
#  11  PreferredPosition  18547 non-null  object
#  12  BestFoot           18547 non-null  object
#  13  WeakFoot           18547 non-null  int64
#  14  AttackWorkrate     18547 non-null  object
#  15  DefenceWorkrate    18547 non-null  object
# ...

# %%
print(fifa.describe(include='all'))
# Out:
#                    ID          Name Nationality           Age  OverallRating  \
# count    18547.000000         18547       18547  18547.000000   18547.000000
# unique            NaN         18392         163           NaN            NaN
# top               NaN  Adama Traoré     England           NaN            NaN
# freq              NaN             3        1697           NaN            NaN
# mean    220055.715372           NaN         NaN     25.238313      66.255459
# std      28005.502234           NaN         NaN      4.675843       6.904721
# min         41.000000           NaN         NaN     16.000000      47.000000
# 25%     204690.500000           NaN         NaN     21.000000      62.000000
# 50%     226414.000000           NaN         NaN     25.000000      66.000000
# 75%     241129.000000           NaN         NaN     29.000000      71.000000
# max     253494.000000           NaN         NaN     42.000000      94.000000
#
# ...

# %% [markdown]
# STEP 2: Variable-by-Variable Summary
# 1. Numerical Variables

# %%
num_vars = ['Age', 'HeightCM', 'WeightKg', 'OverallRating', 'WeakFoot']
fifa[num_vars].describe()
# Out:
#                 Age      HeightCM      WeightKg  OverallRating      WeakFoot
# count  18547.000000  18547.000000  18547.000000   18547.000000  18547.000000
# mean      25.238313    181.335149     75.241759      66.255459      2.944573
# std        4.675843      6.854580      7.088573       6.904721      0.666276
# min       16.000000    154.000000     49.500000      47.000000      1.000000
# 25%       21.000000    177.000000     70.000000      62.000000      3.000000
# 50%       25.000000    181.000000     74.800000      66.000000      3.000000
# 75%       29.000000    186.000000     79.700000      71.000000      3.000000
# max       42.000000    205.000000    110.700000      94.000000      5.000000

# %%
sns.histplot(fifa['Age'], bins=20, kde=True)
plt.title("Age Distribution")
plt.show()

sns.boxplot(x=fifa['Age'])
plt.title("Age Boxplot")
plt.show()

# %%
sns.histplot(fifa['HeightCM'], bins=20, kde=True)
plt.title("HeightCM Distribution")
plt.show()

sns.boxplot(x=fifa['HeightCM'])
plt.title("HeightCM Boxplot")
plt.show()

# %%
sns.histplot(fifa['WeightKg'], bins=20, kde=True)
plt.title("WeightKg Distribution")
plt.show()

sns.boxplot(x=fifa['WeightKg'])
plt.title("WeightKg Boxplot")
plt.show()

# %%
sns.histplot(fifa['OverallRating'], bins=20, kde=True)
plt.title("OverallRating")
plt.show()

sns.boxplot(x=fifa['OverallRating'])
plt.title("OverallRating Boxplot")
plt.show()

# %%
sns.histplot(fifa['WeakFoot'], bins=20, kde=True)
plt.title("WeakFoot Distribution")
plt.show()

sns.boxplot(x=fifa['WeakFoot'])
plt.title("WeakFoot Boxplot")
plt.show()

# %% [markdown]
# 2. Categorical Variables
# (e.g., Nationality, Club, PreferredSide, PreferredPosition, BestFoot, AttackWorkrate, DefenceWorkrate)

# %%
cat_vars = ['Nationality', 'Club', 'PreferredSide', 'PreferredPosition', 'BestFoot', 'AttackWorkrate', 'DefenceWorkrate']

for col in cat_vars:
    plt.figure(figsize=(8,4))
    fifa[col].value_counts().head(10).plot(kind='bar')
    plt.title(f"{col} - Top Categories")
    plt.ylabel("Frequency")
    plt.xticks(rotation=45)
    plt.show()

# %%
print(fifa.shape)
# Out:
# (18547, 48)

# %%
fifa.head()
# Out:
#        ID                          Name Nationality  Age  OverallRating  \
# 0  230212  A. Benjamin Chiamuloira Paes      Brazil   31             79
# 1  248767      A. Pimenta Flora Pimenta    Portugal   20             53
# 2  190883                A.J. DeLaGarza        Guam   31             66
# 3  234290                    Aapo Halme     Finland   21             63
# 4  203504          Aaron Amadi-Holloway       Wales   26             61
#
#              Club  HeightCM HeightFtIn  WeightKg   WeightSt  ... LongShots  \
# 0   Internacional       182       6'0"      79.4   12st 6lb  ...        51
# 1      Venezia FC       184       6'0"      75.3  11st 11lb  ...        42
# 2  Houston Dynamo       174       5'9"      68.1  10st 10lb  ...        36
# 3        Barnsley       197       6'5"      77.7   12st 4lb  ...        18
# 4   Brisbane Roar       189       6'2"      83.3   13st 1lb  ...        49
#
#   Aggression Interceptions  Positioning Vision Penalties  Composure  Marking  \
# ...

# %% [markdown]
# 1️⃣ OverallRating

# %%
print(fifa['OverallRating'].describe())
sns.histplot(fifa['OverallRating'], kde=True)
plt.title("Overall Rating Distribution")
plt.show()
# Out:
# count    18547.000000
# mean        66.255459
# std          6.904721
# min         47.000000
# 25%         62.000000
# 50%         66.000000
# 75%         71.000000
# max         94.000000
# Name: OverallRating, dtype: float64

# %% [markdown]
#  Interpretation:
#
# Roughly normal distribution centered around 65
#
# Most players rated between 60–80
#
# 2️⃣ BallControl

# %%
print(fifa['BallControl'].describe())
sns.histplot(fifa['BallControl'], kde=True)
plt.title("Ball Control Distribution")
plt.show()
# Out:
# count    18547.000000
# mean        58.495336
# std         16.692537
# min          5.000000
# 25%         54.000000
# 50%         63.000000
# 75%         69.000000
# max         96.000000
# Name: BallControl, dtype: float64

# %% [markdown]
# 🔍 Interpretation:
#
# Similar to OverallRating, bell-shaped curve
#
# Average control around 60–75
# 4️⃣ Age

# %%
print(fifa['Age'].describe())
sns.histplot(fifa['Age'], kde=True)
plt.title("Age Distribution")
plt.show()
# Out:
# count    18547.000000
# mean        25.238313
# std          4.675843
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         29.000000
# max         42.000000
# Name: Age, dtype: float64

# %% [markdown]
# 🔍 Interpretation:
#
# Skewed toward younger ages
#
# Most players are between 20 and 30
#
# 5️⃣ HeightCM and WeightKg

# %%
print(fifa[['HeightCM', 'WeightKg']].describe())

sns.histplot(fifa['HeightCM'], kde=True)
plt.title("Height (CM) Distribution")
plt.show()

sns.histplot(fifa['WeightKg'], kde=True)
plt.title("Weight (KG) Distribution")
plt.show()
# Out:
#            HeightCM      WeightKg
# count  18547.000000  18547.000000
# mean     181.335149     75.241759
# std        6.854580      7.088573
# min      154.000000     49.500000
# 25%      177.000000     70.000000
# 50%      181.000000     74.800000
# 75%      186.000000     79.700000
# max      205.000000    110.700000

# %% [markdown]
#  Interpretation:
#
# Height: approximately normal (~180cm)
#
# Weight: slightly skewed toward lower weights
#
# 6️⃣ PreferredSide & PreferredPosition

# %%
fifa['PreferredSide'].value_counts().plot.pie(autopct='%1.1f%%', title='Preferred Side')
plt.ylabel('')
plt.show()

fifa['PreferredPosition'].value_counts().plot.bar()
plt.title("Preferred Position")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Interpretation:
#
# PreferredSide is fairly balanced (right-dominant)
#
# PreferredPosition is unbalanced, with some positions (e.g., ST, CM) far more common
#
# 7️⃣ IntlRep (International Reputation)

# %%
fifa['IntlRep'].value_counts().sort_index().plot(kind='bar') # Changed 'IntllRep' to 'IntlRep'
plt.title("International Reputation (1-5)")
plt.xlabel("Level")
plt.ylabel("Number of Players")
plt.show()

# %% [markdown]
#  Interpretation:
#
# Majority rated 1 or 2
#
# Only elite players rated 4 or 5
#
# 8️⃣ BestFoot

# %%
fifa['BestFoot'].value_counts().plot.pie(autopct='%1.1f%%', title="Preferred Foot")
plt.ylabel('')
plt.show()

# %% [markdown]
# 🔍 Interpretation:
#
# Around 75% right-footed
#
# Unbalanced, which is consistent with real-world data
#
# | Variable          | Type         | Shape       | Distribution   | Balance (if categorical) | Notes             |
# | ----------------- | ------------ | ----------- | -------------- | ------------------------ | ----------------- |
# | OverallRating     | Quantitative | Bell-shaped | Normal         | –                        | Most 60–80        |
# | BallControl       | Quantitative | Bell-shaped | Normal         | –                        | Average 65–75     |
# | Wage              | Quantitative | Long tail   | Right-skewed   | –                        | Outliers dominate |
# | Age               | Quantitative | Skewed      | Right-skewed   | –                        | Most are 20–30    |
# | HeightCM          | Quantitative | Bell-shaped | Normal         | –                        | Avg \~180cm       |
# | WeightKg          | Quantitative | Skewed      | Slightly right | –                        | Avg \~70–80kg     |
# | PreferredSide     | Categorical  | 2 levels    | –              | Slightly imbalanced      | Right more common |
# | PreferredPosition | Categorical  | Many levels | –              | Unbalanced               | ST, CM common     |
# | IntlRep           | Ordinal      | 1–5 levels  | Skewed         | Heavily imbalanced       | Few high reps     |
# | BestFoot          | Categorical  | 2 levels    | –              | Unbalanced               | 75% Right-footed  |

# %% [markdown]
# Task 3 – Generate, visualise and analyse some
# random data

# %%
from numpy.random import default_rng as RNG
import pandas as pd
rng = RNG()
values = ["small", "medium", "large"]
N = 30
x = rng.normal(loc = 100, scale = 20, size = N)
y = rng.uniform(low = -5, high = 5, size = N)
z = rng.choice(values, size = N, replace=True)
data = pd.DataFrame({'norm': x, 'unif': y, 'categ': z})

# %% [markdown]
# ✅ Part i: Visualisation and Statistics
# 🔢 1. Summary Statistics

# %%
# Summary statistics for numeric columns
print(data[['norm', 'unif']].describe())
# Out:
#              norm       unif
# count   30.000000  30.000000
# mean    96.336239   0.135837
# std     19.587340   3.089219
# min     58.653452  -4.719485
# 25%     85.649926  -2.009981
# 50%     92.419393   0.142096
# 75%    101.573105   2.781519
# max    144.914693   4.743658

# %% [markdown]
# 📈 2. Histograms and Density Plots for norm and unif

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot norm
sns.histplot(data['norm'], kde=True)
plt.title("Normal Distribution (mean=100, std=20)")
plt.xlabel("norm")
plt.show()

# Plot unif
sns.histplot(data['unif'], kde=True)
plt.title("Uniform Distribution (range [-5, 5])")
plt.xlabel("unif")
plt.show()

# %% [markdown]
# 📊 3. Boxplots for both

# %%
# Boxplots
sns.boxplot(data=data[['norm', 'unif']])
plt.title("Boxplot of norm and unif")
plt.show()

# %% [markdown]
# 🟦 4. Bar Plot for Categorical Data (categ)

# %%
data['categ'].value_counts().plot(kind='bar', color=['skyblue'])
plt.title("Category Frequencies")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# | Column  | Type         | Distribution | Notes                                    |
# | ------- | ------------ | ------------ | ---------------------------------------- |
# | `norm`  | Quantitative | Normal       | Mean ≈ 100, Std ≈ 20                     |
# | `unif`  | Quantitative | Uniform      | Range ≈ \[-5, 5]                         |
# | `categ` | Categorical  | –            | Random mix of "small", "medium", "large" |

# %% [markdown]
# Vary the value of N , try 100, 1000, 10000. Do the plots get smoother? Do the
# average and standard deviation of the norm column get closer to the expected
# values?

# %%
from numpy.random import default_rng
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

seed = 1
rng = default_rng(seed=seed)

values = ["small", "medium", "large"]
N = 100  # Try 100, 1000, then 10000
x = rng.normal(loc=100, scale=20, size=N)
y = rng.uniform(low=-5, high=5, size=N)
z = rng.choice(values, size=N, replace=True)

data = pd.DataFrame({'norm': x, 'unif': y, 'categ': z})

# Summary stats
print(data['norm'].mean(), data['norm'].std())

# Plot histograms
sns.histplot(data['norm'], kde=True)
plt.title(f"Normal distribution (N={N})")
plt.show()
# Out:
# 98.52775757454107 17.116934376886107

# %%
from numpy.random import default_rng
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

seed = 1
rng = default_rng(seed=seed)

values = ["small", "medium", "large"]
N = 1000  # Try 100, 1000, then 10000
x = rng.normal(loc=100, scale=20, size=N)
y = rng.uniform(low=-5, high=5, size=N)
z = rng.choice(values, size=N, replace=True)

data = pd.DataFrame({'norm': x, 'unif': y, 'categ': z})

# Summary stats
print(data['norm'].mean(), data['norm'].std())

# Plot histograms
sns.histplot(data['norm'], kde=True)
plt.title(f"Normal distribution (N={N})")
plt.show()
# Out:
# 98.9149355447327 19.735092771499072

# %%
from numpy.random import default_rng
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

seed = 1
rng = default_rng(seed=seed)

values = ["small", "medium", "large"]
N = 10000  # Try 100, 1000, then 10000
x = rng.normal(loc=100, scale=20, size=N)
y = rng.uniform(low=-5, high=5, size=N)
z = rng.choice(values, size=N, replace=True)

data = pd.DataFrame({'norm': x, 'unif': y, 'categ': z})

# Summary stats
print(data['norm'].mean(), data['norm'].std())

# Plot histograms
sns.histplot(data['norm'], kde=True)
plt.title(f"Normal distribution (N={N})")
plt.show()
# Out:
# 99.78174197758308 19.97091916352064

# %% [markdown]
# N = 100: Histogram is bumpy and irregular.
#
# N = 1000: Smoother, more bell-shaped.
#
# N = 10000: Very smooth bell curve, closely resembling a normal distribution.
#
# This is because more samples give better representation of the true distribution.
#
# | N     | Mean (norm)  | Std Dev (norm) |
# | ----- | ------------ | -------------- |
# | 100   | ≈ 99–101     | ≈ 18–22        |
# | 1000  | ≈ 99.5–100.5 | ≈ 19.5–20.5    |
# | 10000 | ≈ 100        | ≈ 20           |
#
# As N increases:
#
# Mean → 100
#
# Std → 20
#
# This is due to the Law of Large Numbers, which says the sample statistics converge to population values as sample size increases.
#
# | N     | Smoothness | Accuracy of Stats |
# | ----- | ---------- | ----------------- |
# | 100   | Rough      | Low               |
# | 1000  | Medium     | Medium            |
# | 10000 | Smooth     | High              |
